# %% [markdown]
# # Testa Olika settings och hyperparametrar

# %%
import pandas as pd
import numpy as np
import fixa_features as ff
import fixa_mer_features as ff2

from catboost import CatBoostClassifier, Pool
from catboost.utils import get_confusion_matrix 

### Läs in hela samlingen komplett.csv ###
df=pd.read_csv('mer_komplett.csv')
df.drop('tid',axis=1,inplace=True)

### Rätta ev felaktigheter
df=ff2.fixa_mer_features(df,hist=False)
df.lopp_dist=df.lopp_dist.astype('float')
df.plac = (df.plac==1)*1
print(df.plac.value_counts())  # CatBoost fungerar bättre med 0,1 än False, True
print(df.start.value_counts())
# Out:
# (37824, 62)
# fixa features start (37824, 62)
# efter fixa_features (37824, 63)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37824 entries, 0 to 37823
# Data columns (total 63 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datum      37824 non-null  object
#  1   avd        37824 non-null  int64
#  2   häst       37824 non-null  object
#  3   bana       37824 non-null  object
#  4   dist       37824 non-null  int64
#  5   h1_bana    37824 non-null  object
#  6   h1_dat     37824 non-null  object
#  7   h1_dist    37824 non-null  float64
#  8   h1_kmtid   37820 non-null  object
#  9   h1_kusk    37824 non-null  object
#  10  h1_odds    37771 non-null  object
#  11  h1_plac    37817 non-null  object
#  12  h1_pris    34738 non-null  float64
#  13  h1_spår    35008 non-null  float64
#  14  h2_bana    37824 non-null  object
#  15  h2_dat     37824 non-null  object
#  16  h2_dist    37824 non-null  float64
#  17  h2_kmtid   37821 non-null  object
#  18  h2_kusk    37824 non-null  object
#  19  h2_odds    37801 non-null  object
#  20  h2_plac    37823 non-null  object
#  21  h2_pris    34227 non-null  float64
#  22  h2_spår    34611 non-null  float64
#  23  h3_bana    37818 non-null  object
#  24  h3_dat     37818 non-null  object
#  25  h3_dist    37818 non-null  float64
#  26  h3_kmtid   37814 non-null  object
#  27  h3_kusk    37818 non-null  object
#  28  h3_odds    37793 non-null  object
#  29  h3_plac    37817 non-null  object
#  30  h3_pris    33832 non-null  float64
#  31  h3_spår    34272 non-null  float64
#  32  h4_bana    37796 non-null  object
#  33  h4_dat     37796 non-null  object
#  34  h4_dist    37796 non-null  float64
#  35  h4_kmtid   37792 non-null  object
#  36  h4_kusk    37796 non-null  object
#  37  h4_odds    37756 non-null  object
#  38  h4_plac    37796 non-null  object
#  39  h4_pris    33447 non-null  float64
#  40  h4_spår    34001 non-null  float64
#  41  h5_bana    37741 non-null  object
#  42  h5_dat     37741 non-null  object
#  43  h5_dist    37741 non-null  float64
#  44  h5_kmtid   37733 non-null  object
#  45  h5_kusk    37741 non-null  object
#  46  h5_odds    37696 non-null  object
#  47  h5_plac    37739 non-null  object
#  48  h5_pris    33095 non-null  float64
#  49  h5_spår    33750 non-null  float64
#  50  kr         37824 non-null  object
#  51  kusk       37824 non-null  object
#  52  kön        37824 non-null  object
#  53  lopp_dist  37824 non-null  object
#  54  plac       37824 non-null  float64
#  55  podds      37824 non-null  float64
#  56  pris       37824 non-null  float64
#  57  spår       37824 non-null  int32
#  58  start      37824 non-null  int64
#  59  streck     37740 non-null  object
#  60  vodds      37824 non-null  float64
#  61  ålder      37824 non-null  int64
#  62  bins       37824 non-null  int64
# dtypes: float64(19), int32(1), int64(5), object(38)
# memory usage: 18.3+ MB
# None
# bana 0
# kusk 0
# avd 0
# spår==0             datum            bana  avd              häst  spår  start  vodds
# 20423  2018-05-13  CHARLOTTENLUND    1       GREECE BOKO     0      0  66.06
# 20427  2018-05-13  CHARLOTTENLUND    1     UNCERTAIN AGE     0      0   7.84
# 20431  2018-05-13  CHARLOTTENLUND    2  EXCLAMATION MARK     0      0  11.93
# 20434  2018-05-13  CHARLOTTENLUND    2      RAKET BRODDE     0      0   4.05
# 20435  2018-05-13  CHARLOTTENLUND    2     TWITTER LASER     0      0  10.03
# ...           ...             ...  ...               ...   ...    ...    ...
# 24902  2018-12-28           ÅRHUS    7    A'KA SJÆL SKOV     0      0  72.75
# 24903  2018-12-28           ÅRHUS    7     BELLA HØJGÅRD     0      0  44.31
# 24904  2018-12-28           ÅRHUS    7     DAMIEN SHADOW     0      0  52.32
# 24905  2018-12-28           ÅRHUS    7       DEKADENT K.     0      0  32.40
# 24913  2018-12-28           ÅRHUS    7   SOMETHING FISHY     0      0  21.98
#
# [89 rows x 7 columns]
# spår 0
# Ålder 0
# kön 0
# dist 0
# lopp_dist 0
# streck efter med NaNs: 142
# ta hand om outliers efter merge och matchningar innan predict
# 0    34477
# 1     3347
# Name: plac, dtype: int64
# 0    26646
# 1    11178
# Name: start, dtype: int64

# %%
# bestäm datum för train/test split
# mitt_datum = df.iloc[int(df.shape[0]/2)].datum  # någonstans i mitten
# mitt_datum = '2020-10-10'  # annat datum under inledande testningar
mitt_datum = '2019-03-01'  # annat datum under inledande testningar
mitt_datum
# Out:
# '2019-03-01'

# %%
def get_rows_with_dates(df,n):
    # get the first rows in df with the n first dates
    dates = df.datum.unique()[:n]
    rows = df[df.datum=='inget datum']   # empty with the same columns as df
    for d in dates:
        rows = pd.concat([rows,df[df.datum==d]], copy=True, ignore_index=True)
    print('rows',rows.shape)
    return rows

# %%
def move_rows_from_A_to_B(A,B,n):
    # select the rows for the n first datum in A
    move = get_rows_with_dates(A,n)
    a=A.iloc[move.shape[0]:] # remove the n first datum
    
    # add to the end of B
    b = pd.concat([B,move],ignore_index=True,copy=True)
    return a,b

# %%
# split med datum
def initsplit_my_data(df,mitt_datum):
    train=df[df.datum<=mitt_datum]
    test_all = df[df.datum>mitt_datum]

    print('Check that this is True',test_all.shape[0]+train.shape[0] == df.shape[0])
    train.shape,test_all.shape

    return train,test_all,

# %%
def catfit(trainPool, testPool,auto=None,use_best=False,early=200,iterations=2000):
    
    model = CatBoostClassifier(  
        random_seed=2021,
        iterations=iterations,              
        auto_class_weights=auto ,
        # scale_pos_weight = 10,
        eval_metric = 'AUC',
        loss_function = 'Logloss',
        early_stopping_rounds=early,
        )
    if use_best:
        model.fit(trainPool,
        use_best_model=True,
        eval_set=testPool,
        verbose = 100
        )
    else:            
        model.fit(trainPool,
        use_best_model=False,
        eval_set=testPool,
        verbose = 100
        )
    
    return model

# %% [markdown]
# ##  Finn bästa feature-komb (utan odds).
# ### Vodds, bins och podds är osäkra features eftersom de ändrar sig efter att v75 börjat.
# ### streck borde vara med

# %%
all_features = ['häst','kusk','bana','kön','lopp_dist','dist','kr','streck','bins','podds','vodds','pris','spår','start','ålder','plac']
cat_features = ['häst','kusk','bana','kön']

### Bestäm features för train ##

sel_feat = cat_features + ['lopp_dist','kr','pris','spår','start','streck','ålder']

# text='early, AUC, Balanced|'
# text='early, AUC, SqrtBal|'
# text='early, AUC, None|'
# text='2000, AUC, Balanced|'
# text='2000, AUC, Bal use_b|'
# text='early, F1, Balanced|'
# text='early, AUC, scale|'
text='allt utom odds|'

# Dataframe som sparar resultaten
# dfRes = pd.DataFrame(columns=[ 'text', 'F1', 'Recall',	'Precision', 'Accuracy', 'AUC','b_iter','model'])
dfRes = pd.read_csv('testResults.csv')

# %%
### split och pool ###

train, test = initsplit_my_data(df,mitt_datum)

trainPool = Pool(data=train[sel_feat], label=train.plac, cat_features=cat_features)
testPool = Pool(data=test[sel_feat], label=test.plac, cat_features=cat_features)

print(f'train last {train.iloc[-1].datum} test first {test.iloc[0].datum}')
print(sel_feat)
# Out:
# Check that this is True True
# train last 2019-02-23 test first 2019-03-02
# ['häst', 'kusk', 'bana', 'kön', 'lopp_dist', 'kr', 'pris', 'spår', 'start', 'streck', 'ålder']

# %% [markdown]
# - Kör med all under testningarna
# - Parametrar: balanced/sqrtBalanced/None, eval_test='AUC','F1'
# - Testa med olika iterations med och utan early
# - Kolla framför allt på F1

# %%
use_best = True
early=200
iterations=2000

model = catfit(trainPool, testPool, auto='Balanced',use_best=use_best,early=early,iterations=iterations)

# %%
### mätningar och spara i dfRes ###
eval = model.eval_metrics(testPool,['Accuracy','F1','Precision','Recall','AUC'])
x=0 
x=model.get_best_iteration()
dfRes.loc[len(dfRes)] = [text, round(np.mean(eval['F1']),3),round(np.mean(eval['Recall']),3), round(np.mean(eval['Precision']),3),  round(np.mean(eval['Accuracy']),3), round(np.mean(eval['AUC']),3), x, model]

model.feature_names_

# %%
pd.set_option('display.width',100)

print(dfRes[['text', 'F1', 'Recall', 'Precision', 'Accuracy', 'AUC', 'b_iter']])

# %%
# Skriv ut feature importance och confusion matrix
print(model.get_feature_importance(prettified=True))
print()
print(get_confusion_matrix(model,data=testPool))

# %%
dfRes.sort_values(by=['F1','Recall'],ascending=False)

# %%
test.häst.value_counts()

# %%
dfRes.to_csv('testResults.csv',index=False)
model.save_model('testmodell_podds')

# %%
all_features = ['häst','kusk','bana','kön','lopp_dist','dist','kr','streck','bins','podds','vodds','pris','spår','start','ålder','plac']
cat_features = ['häst','kusk']
#sel_feat = cat_features + ['lopp_dist','kr','bins','podds','vodds','pris','spår','start','streck','ålder']
sel_feat = cat_features + []


def fit(train,test,cat_features):
    trainPool = Pool(data=train, label=train.plac, cat_features=cat_features)
    testPool = Pool(data=test, label=test.plac, cat_features=cat_features)

    model = catfit(trainPool, testPool, auto='Balanced',use_best=True,early=200,iterations=2000)

    return model

# %%
print(model.get_feature_importance(prettified=True))
print(get_confusion_matrix(model,testPool))
eval = model.eval_metrics(testPool,['Accuracy','F1','Precision','Recall','AUC'])
print(round(np.mean(eval['F1']),3), round(np.mean(eval['Recall']),3), round(np.mean(eval['Precision']),3),  round(np.mean(eval['Accuracy']),3))
# np.mean(model.eval_metrics(testPool,['AUC'])['AUC'])

# %%
def ettVarv(d,lr,add_features):
    from catboost import Pool, cv
    all_features = ['häst','kusk','bana','kön','lopp_dist','dist','kr','streck','bins','podds','vodds','pris','spår','start','ålder','plac']
    cat_features=['häst','kusk','bana','kön']
    sel_features=cat_features + add_features
    cv_data = test[sel_features]

    labels=test.plac

    cv_dataset = Pool(data=cv_data,
                    label=labels,
                    cat_features=cat_features)

    params = {"iterations": 1000,
            "depth": d,
            "learning_rate": lr,
            "auto_class_weights": "Balanced",
            "eval_metric": "Accuracy",
            "loss_function": "Logloss",
            "verbose": 50}

    scores = cv(cv_dataset,
                params,
                shuffle=False,
                early_stopping_rounds=200,
                type='TimeSeries',
                fold_count=52, 
                )
    return scores  

def addScores(dfcv,score,d,lr,add_features):   
    ix= scores[scores['test-Accuracy-mean'].max()==scores['test-Accuracy-mean']].index.values[0]
    rad=scores.loc[ix,['test-Accuracy-mean','test-Logloss-mean','iterations']].tolist()+ [d,lr,add_features]
    dfcv.loc[len(dfcv)] = rad
    dfcv.sort_values(by='accuracy',ascending=False,inplace=True)

    return dfcv

# %%
add_features = ['lopp_dist','streck']
for d in [1,2,3,4,5,6]:
    for lr in [0.01,0.03,0.06,0.08]:
        print(f'djup={d} lr={lr}')
        scores = ettVarv(d,lr,add_features)
        dfcv = addScores(dfcv,scores,d,lr,add_features)
        print(dfcv)
# Out:
# 0:	learn: 0.7481755	test: 0.7398496	best: 0.7398496 (0)	total: 741ms	remaining: 12m 20s
# 50:	learn: 0.7553151	test: 0.7395696	best: 0.7423474 (16)	total: 1m	remaining: 18m 45s
# 100:	learn: 0.7552079	test: 0.7393950	best: 0.7423474 (16)	total: 2m 1s	remaining: 17m 58s
# 150:	learn: 0.7554792	test: 0.7393684	best: 0.7423474 (16)	total: 3m 2s	remaining: 17m 3s
# 200:	learn: 0.7561780	test: 0.7405365	best: 0.7423474 (16)	total: 4m 2s	remaining: 16m 5s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7481755	test: 0.7398496	best: 0.7398496 (0)	total: 713ms	remaining: 11m 51s
# 50:	learn: 0.7547215	test: 0.7388854	best: 0.7413387 (12)	total: 1m	remaining: 18m 47s
# 100:	learn: 0.7572635	test: 0.7388189	best: 0.7413387 (12)	total: 2m 1s	remaining: 17m 59s
# 150:	learn: 0.7586988	test: 0.7375212	best: 0.7413387 (12)	total: 3m 2s	remaining: 17m 4s
# 200:	learn: 0.7598501	test: 0.7367705	best: 0.7413387 (12)	total: 4m 3s	remaining: 16m 8s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.

# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7490847	test: 0.7367496	best: 0.7367496 (0)	total: 3.69s	remaining: 1h 1m 26s
# 50:	learn: 0.7783430	test: 0.7322149	best: 0.7408336 (8)	total: 3m 25s	remaining: 1h 3m 52s
# 100:	learn: 0.8020828	test: 0.7238128	best: 0.7408336 (8)	total: 6m 55s	remaining: 1h 1m 38s
# 150:	learn: 0.8282506	test: 0.7071989	best: 0.7408336 (8)	total: 10m 45s	remaining: 1h 29s
# 200:	learn: 0.8508525	test: 0.6965952	best: 0.7408336 (8)	total: 14m 41s	remaining: 58m 25s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7496007	test: 0.7378037	best: 0.7378037 (0)	total: 3.98s	remaining: 1h 6m 21s
# 50:	learn: 0.7574018	test: 0.7399468	best: 0.7408109 (49)	total: 3m 31s	remaining: 1h 5m 38s
# 100:	learn: 0.7596897	test: 0.7395913	best: 0.7409007 (57)	total: 7m 7s	remaining: 1h 3m 24s
# 150:	learn: 0.7628053	test: 0.7367637	best: 0.7409007 (57)	total: 10m 54s	remaining: 1h 1m 21s
# 200:	learn: 0.7671335	test: 0.7360672	best: 0.7409007 (57)	total: 14m 45s	remaining: 58m 38s
# 250:	learn: 0.7717003	test: 0.7331281	best: 0.7409007 (57)	total: 18m 37s	remaining: 55m 34s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7496007	test: 0.7378037	best: 0.7378037 (0)	total: 4.18s	remaining: 1h 9m 36s
# 50:	learn: 0.7618159	test: 0.7376491	best: 0.7398249 (19)	total: 3m 34s	remaining: 1h 6m 26s
# 100:	learn: 0.7773117	test: 0.7328748	best: 0.7398249 (19)	total: 7m 27s	remaining: 1h 6m 26s
# 150:	learn: 0.7898201	test: 0.7303118	best: 0.7398249 (19)	total: 11m 23s	remaining: 1h 4m 1s
# 200:	learn: 0.8019533	test: 0.7241991	best: 0.7398249 (19)	total: 15m 14s	remaining: 1h 33s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7496007	test: 0.7378037	best: 0.7378037 (0)	total: 3.97s	remaining: 1h 6m 7s
# 50:	learn: 0.7752617	test: 0.7294261	best: 0.7399464 (6)	total: 3m 38s	remaining: 1h 7m 54s
# 100:	learn: 0.8000818	test: 0.7251645	best: 0.7399464 (6)	total: 7m 20s	remaining: 1h 5m 21s
# 150:	learn: 0.8262494	test: 0.7126691	best: 0.7399464 (6)	total: 11m 14s	remaining: 1h 3m 12s
# 200:	learn: 0.8543535	test: 0.7017619	best: 0.7399464 (6)	total: 15m 26s	remaining: 1h 1m 22s
# Stopped by overfitting detector  (200 iterations wait)
# 0:	learn: 0.7496007	test: 0.7378037	best: 0.7378037 (0)	total: 4.22s	remaining: 1h 10m 13s
# 50:	learn: 0.7846596	test: 0.7304056	best: 0.7395990 (17)	total: 3m 35s	remaining: 1h 6m 42s
# 100:	learn: 0.8169273	test: 0.7163511	best: 0.7395990 (17)	total: 7m 20s	remaining: 1h 5m 18s
# 150:	learn: 0.8536314	test: 0.7009362	best: 0.7395990 (17)	total: 11m 24s	remaining: 1h 4m 11s
# 200:	learn: 0.8816144	test: 0.6864043	best: 0.7395990 (17)	total: 15m 35s	remaining: 1h 1m 58s
# Stopped by overfitting detector  (200 iterations wait)

# %%
# dfcv = pd.DataFrame(columns = ['accuracy', 'logloss', 'iter', 'depth', 'learn_r','feat'])
# dfcv = addScores(dfcv,scores,d,lr,add_features)

# %%
dfcv
# Out:
#     accuracy   logloss  iter depth  learn_r                 feat
# 6   0.744034  0.662642   3.0     2     0.03  [lopp_dist, streck]
# 3   0.743115  0.548918  28.0     1     0.06  [lopp_dist, streck]
# 5   0.743051  0.674944   6.0     2     0.01  [lopp_dist, streck]
# 17  0.742526  0.673803   6.0     5     0.01  [lopp_dist, streck]
# 1   0.742347  0.654794  16.0     1     0.01  [lopp_dist, streck]
# 19  0.742296  0.570665  13.0     5     0.06  [lopp_dist, streck]
# 11  0.742246  0.626195   4.0     3     0.06  [lopp_dist, streck]
# 15  0.742182  0.565165  15.0     4     0.06  [lopp_dist, streck]
# 0   0.742048  0.589511  34.0     1     0.02  [lopp_dist, streck]
# 7   0.741841  0.627880   4.0     2     0.06  [lopp_dist, streck]
# 4   0.741581  0.599742   6.0     1     0.08  [lopp_dist, streck]
# 2   0.741339  0.619850  12.0     1     0.03  [lopp_dist, streck]
# 8   0.741226  0.561633  12.0     2     0.08  [lopp_dist, streck]
# 13  0.741037  0.661895  11.0     4     0.01  [lopp_dist, streck]
# 14  0.741013  0.612845  12.0     4     0.03  [lopp_dist, streck]
# 21  0.740901  0.591680  57.0     6     0.01  [lopp_dist, streck]
# 16  0.740839  0.557097  13.0     4     0.08  [lopp_dist, streck]
# 20  0.740834  0.578713   8.0     5     0.08  [lopp_dist, streck]
# 10  0.740801  0.572887  27.0     3     0.03  [lopp_dist, streck]
# 18  0.739971  0.621142  10.0     5     0.03  [lopp_dist, streck]
# 23  0.739946  0.608458   6.0     6     0.06  [lopp_dist, streck]
# 12  0.739894  0.568993  10.0     3     0.08  [lopp_dist, streck]
# 9   0.739850  0.607517  44.0     3     0.01  [lopp_dist, streck]
# 22  0.739825  0.589680  19.0     6     0.03  [lopp_dist, streck]
# 24  0.739599  0.549416  17.0     6     0.08  [lopp_dist, streck]

# %%
def addFeatScore(dfcv,accuracy,logloss,iterations,d,lr,add_features):   
    dfcv.loc[len(dfcv)] = [accuracy,logloss,iterations,d,lr,add_features]
    dfcv.sort_values(by='accuracy',ascending=False,inplace=True)

    return dfcv

# %%
d=2
lr=0.03
from catboost import CatBoostClassifier
model=CatBoostClassifier(learning_rate=lr,depth=d,iterations=1000,auto_class_weights="Balanced",eval_metric='Accuracy',loss_function='Logloss',verbose=100,early_stopping_rounds=200)
cat_feat=['häst','kusk']
add_features = [  'streck']
sel_feat=cat_feat+add_features
trainPool = Pool(data=train[sel_feat], label=train.plac, cat_features=cat_feat)
testPool = Pool(data=test[sel_feat], label=test.plac, cat_features=cat_feat)

score=model.fit(trainPool,
        use_best_model=True,
        eval_set=testPool,
        verbose = 100,
)
# Out:
# 0:	learn: 0.7379974	test: 0.7317111	best: 0.7317111 (0)	total: 28.3ms	remaining: 28.3s
# 100:	learn: 0.7487231	test: 0.7416212	best: 0.7422004 (84)	total: 4.79s	remaining: 42.6s
# 200:	learn: 0.7501086	test: 0.7426632	best: 0.7433806 (191)	total: 9.44s	remaining: 37.5s
# 300:	learn: 0.7511740	test: 0.7374985	best: 0.7433806 (191)	total: 14s	remaining: 32.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.743380622
# bestIteration = 191
#
# Shrink model to first 192 iterations.

# %%
accuracy = model.get_best_score()['validation']['Accuracy']

# dfcv=addScores(dfcv,score,d,lr,add_features)
model.best_iteration_
Logloss = model.get_best_score()['validation']['Logloss']

dfcv=addFeatScore(dfcv.copy(),accuracy,Logloss,model.best_iteration_,d,lr,add_features)
dfcv
# Out:
#     accuracy   logloss   iter depth  learn_r  \
# 30  0.744343  0.530295  206.0     2     0.03
# 6   0.744034  0.662642    3.0     2     0.03
# 29  0.743928  0.530184  214.0     2     0.03
# 28  0.743915  0.530680  209.0     2     0.03
# 32  0.743913  0.532516  116.0     2     0.03
# 25  0.743895  0.530435  223.0     2     0.03
# 26  0.743630  0.531666  127.0     2     0.03
# 27  0.743467  0.530939  168.0     2     0.03
# 33  0.743381  0.533167  191.0     2     0.03
# 3   0.743115  0.548918   28.0     1     0.06
# 5   0.743051  0.674944    6.0     2     0.01
# 31  0.742636  0.530578  139.0     2     0.03
# 17  0.742526  0.673803    6.0     5     0.01
# 1   0.742347  0.654794   16.0     1     0.01
# 19  0.742296  0.570665   13.0     5     0.06
# 11  0.742246  0.626195    4.0     3     0.06
# 15  0.742182  0.565165   15.0     4     0.06
# 0   0.742048  0.589511   34.0     1     0.02
# 7   0.741841  0.627880    4.0     2     0.06
# 4   0.741581  0.599742    6.0     1     0.08
# 2   0.741339  0.619850   12.0     1     0.03
# 8   0.741226  0.561633   12.0     2     0.08
# 13  0.741037  0.661895   11.0     4     0.01
# 14  0.741013  0.612845   12.0     4     0.03
# 21  0.740901  0.591680   57.0     6     0.01
# 16  0.740839  0.557097   13.0     4     0.08
# 20  0.740834  0.578713    8.0     5     0.08
# 10  0.740801  0.572887   27.0     3     0.03
# 18  0.739971  0.621142   10.0     5     0.03
# 23  0.739946  0.608458    6.0     6     0.06
# 12  0.739894  0.568993   10.0     3     0.08
# 9   0.739850  0.607517   44.0     3     0.01
# 22  0.739825  0.589680   19.0     6     0.03
# 24  0.739599  0.549416   17.0     6     0.08
#
#                                                  feat
# 30                                     [streck, spår]
# 6                                 [lopp_dist, streck]
# 29                              [streck, spår, ålder]
# 28                          [kr, streck, spår, ålder]
# 32                                           [streck]
# 25  [lopp_dist, kr, streck, pris, spår, start, ålder]
# 26             [kr, streck, pris, spår, start, ålder]
# 27                    [kr, streck, pris, spår, ålder]
# 33                                           [streck]
# 3                                 [lopp_dist, streck]
# 5                                 [lopp_dist, streck]
# 31                                     [streck, spår]
# 17                                [lopp_dist, streck]
# 1                                 [lopp_dist, streck]
# 19                                [lopp_dist, streck]
# 11                                [lopp_dist, streck]
# 15                                [lopp_dist, streck]
# 0                                 [lopp_dist, streck]
# 7                                 [lopp_dist, streck]
# 4                                 [lopp_dist, streck]
# 2                                 [lopp_dist, streck]
# 8                                 [lopp_dist, streck]
# 13                                [lopp_dist, streck]
# 14                                [lopp_dist, streck]
# 21                                [lopp_dist, streck]
# 16                                [lopp_dist, streck]
# 20                                [lopp_dist, streck]
# 10                                [lopp_dist, streck]
# 18                                [lopp_dist, streck]
# 23                                [lopp_dist, streck]
# 12                                [lopp_dist, streck]
# 9                                 [lopp_dist, streck]
# 22                                [lopp_dist, streck]
# 24                                [lopp_dist, streck]

# %%
feat_imp=model.get_feature_importance(prettified=True)
print(feat_imp)
bort=feat_imp.loc[len(feat_imp)-1][0]
# add_features.remove(bort)
add_features
# Out:
#   Feature Id  Importances
# 0     streck    91.910658
# 1       häst     4.870891
# 2       kusk     3.218451
# ['streck']

# %%
dfcv
# Out:
#     accuracy   logloss  iter depth  learn_r                 feat
# 6   0.744034  0.662642   3.0     2     0.03  [lopp_dist, streck]
# 3   0.743115  0.548918  28.0     1     0.06  [lopp_dist, streck]
# 5   0.743051  0.674944   6.0     2     0.01  [lopp_dist, streck]
# 17  0.742526  0.673803   6.0     5     0.01  [lopp_dist, streck]
# 1   0.742347  0.654794  16.0     1     0.01  [lopp_dist, streck]
# 19  0.742296  0.570665  13.0     5     0.06  [lopp_dist, streck]
# 11  0.742246  0.626195   4.0     3     0.06  [lopp_dist, streck]
# 15  0.742182  0.565165  15.0     4     0.06  [lopp_dist, streck]
# 0   0.742048  0.589511  34.0     1     0.02  [lopp_dist, streck]
# 7   0.741841  0.627880   4.0     2     0.06  [lopp_dist, streck]
# 4   0.741581  0.599742   6.0     1     0.08  [lopp_dist, streck]
# 2   0.741339  0.619850  12.0     1     0.03  [lopp_dist, streck]
# 8   0.741226  0.561633  12.0     2     0.08  [lopp_dist, streck]
# 13  0.741037  0.661895  11.0     4     0.01  [lopp_dist, streck]
# 14  0.741013  0.612845  12.0     4     0.03  [lopp_dist, streck]
# 21  0.740901  0.591680  57.0     6     0.01  [lopp_dist, streck]
# 16  0.740839  0.557097  13.0     4     0.08  [lopp_dist, streck]
# 20  0.740834  0.578713   8.0     5     0.08  [lopp_dist, streck]
# 10  0.740801  0.572887  27.0     3     0.03  [lopp_dist, streck]
# 18  0.739971  0.621142  10.0     5     0.03  [lopp_dist, streck]
# 23  0.739946  0.608458   6.0     6     0.06  [lopp_dist, streck]
# 12  0.739894  0.568993  10.0     3     0.08  [lopp_dist, streck]
# 9   0.739850  0.607517  44.0     3     0.01  [lopp_dist, streck]
# 22  0.739825  0.589680  19.0     6     0.03  [lopp_dist, streck]
# 24  0.739599  0.549416  17.0     6     0.08  [lopp_dist, streck]
